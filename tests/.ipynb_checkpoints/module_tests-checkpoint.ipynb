# %% [markdown]
# ## Spectral Dataset

# %%
import pandas as pd
import numpy as np

from data_loader.dataset import SpectralDataset
from data_loader.dataset import Device

# %% [markdown]
# ## Data loading

# %%
data_path = "../spectral_data"
dataset = SpectralDataset(data_path, device= Device.BIO_SCIENCE)

# %% [markdown]
# ## Testing the loading functions

# %%
devices= Device.get_devices()
device_names = Device.get_device_names()

for _device, _device_name in zip(devices, device_names):
    dataset = SpectralDataset(data_path, device=_device)
    print(_device_name, len(dataset), sep='\t|\t')
# Out:
# BIO_SCIENCE	|	1591
# SCAN_CODER	|	1684
# LOW_COST	|	1614

# %% [markdown]
# ## Testing dataloading for scan coder

# %%
dataset= SpectralDataset(data_path, devices[1])
dataset[0]
# Out:
# array([0.052081, 0.063122, 0.064846, 0.103572, 0.114943, 0.120739,
#        0.107806, 0.091979, 0.083951, 0.575549, 0.586088, 0.592532,
#        3.      ], dtype=float32)

# %% [markdown]
# ## Testing dataloading for low cost spectrometer

# %%
dataset = SpectralDataset(data_path, Device.LOW_COST)
wavelenght, spectral = dataset[0]

arr1 = np.array([1, 2, 3])
arr2 = np.array([3, 4, 5])
np.vstack([arr1, arr2])
# Out:
# array([[1, 2, 3],
#        [3, 4, 5]])
