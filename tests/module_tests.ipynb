# %% [markdown]
# ## Spectral Dataset

# %%
from data_loader.dataset import SpectralDataset
from data_loader.dataset import Device

# %% [markdown]
# ## Data loading

# %%
data_path = "../spectral_data"
dataset = SpectralDataset(data_path)
target_len = len(dataset.high_end_csvs)

f'Target lenght: {target_len}'
# Out:
# 'Target lenght: 3185'

# %% [markdown]
# ## Assertion of eliminated state objects

# %%
dataset.tracked_csvs
# Out:
# ['../spectral_data/Multi-spectral sensor data/spectral_data_week3/Scan coder/week3.csv',
#  '../spectral_data/Multi-spectral sensor data/spectral_data_week1/Scancorder/week1.csv',
#  '../spectral_data/Multi-spectral sensor data/spectral_data_week5/Scancorder/week5.csv',
#  '../spectral_data/Multi-spectral sensor data/spectral_data_week4/Scancorder/week4.csv',
#  '../spectral_data/Multi-spectral sensor data/spectral_data_week6/Scancorder/week6.csv',
#  '../spectral_data/Multi-spectral sensor data/spectral_data_week2/Scancorder/week2.csv']
