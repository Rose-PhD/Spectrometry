# %% [markdown]
# ## Spectral Dataset

# %%
import pandas as pd
import numpy as np

from data_loader.dataset import SpectralDataset
from data_loader.dataset import Device

# %% [markdown]
# ## Data loading

# %%
data_path = "../spectral_data"
dataset = SpectralDataset(data_path)
target_len = len(dataset.high_end_csvs)

f'Target lenght: {target_len}'
# Out:
# 'Target lenght: 3185'

# %% [markdown]
# ## Assertion of eliminated state objects

# %%
np.array(dataset.get_scan_corder_item(0)).astype(np.float32)
# Out:
# array([0.052081, 0.063122, 0.064846, 0.103572, 0.114943, 0.120739,
#        0.107806, 0.091979, 0.083951, 0.575549, 0.586088, 0.592532,
#        3.      ], dtype=float32)
